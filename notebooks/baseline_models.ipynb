# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import confusion_matrix, classification_report, top_k_accuracy_score
from sklearn.naive_bayes import BernoulliNB, CategoricalNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
X = np.loadtxt('../data/processed/X_7steps.csv', dtype=np.int8, delimiter=',')
y = np.loadtxt('../data/processed/y_7steps.csv', dtype=np.int8, delimiter=',')

print('X shape:', X.shape)
print('y shape:', y.shape)
# Out:
# X shape: (211, 9)
# y shape: (211,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=5)

print('X Train shape:', X_train.shape)
print('X Test shape:', X_test.shape)
print('y Train shape:', y_train.shape)
print('y Test shape:', y_test.shape)
# Out:
# X Train shape: (189, 9)
# X Test shape: (22, 9)
# y Train shape: (189,)
# y Test shape: (22,)

# %%
rf = RandomForestClassifier(100)
rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.5

# %%
bnb = BernoulliNB()
bnb.fit(X_train, y_train)
bnb.score(X_test, y_test)
# Out:
# 0.13636363636363635

# %%
ab = AdaBoostClassifier()
ab.fit(X_train, y_train)
ab.score(X=X_test, y=y_test)
# Out:
# c:\Users\segav\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# 0.13636363636363635

# %%
cnb = CategoricalNB()
cnb.fit(X_train, y_train)
cnb.score(X_test, y_test)
# Out:
# 0.36363636363636365

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
gnb.score(X_test, y_test)
# Out:
# 0.045454545454545456

# %%
knn = KNeighborsClassifier(128)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 0.22727272727272727
